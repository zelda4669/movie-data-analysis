# %% [markdown]
# # Return on Investment

# %% [markdown]
# Critical for any new business venture is to add value as quickly as possible. I have analyzed recent movie budgets compared to their domestic and global gross to help identify patterns.

# %%
#import necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

#import dataset
df = pd.read_csv('data/tn.movie_budgets.csv', index_col=0)

# %%
#Add columns to compute the difference between budget and gross for 
df['Domestic Profit'] = df['domestic_gross'] - df['production_budget']
df['Global ROI'] = df['worldwide_gross'] - df['production_budget']
df['release_date'] = pd.to_datetime(df['release_date'])
df['Year'] = df['release_date'].dt.year
df = df.loc[df['Year'] >= 2010]

# %%
df
# Out:
#    release_date                                        movie  \
# id
# 2    2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 3    2019-06-07                                 Dark Phoenix
# 4    2015-05-01                      Avengers: Age of Ultron
# 5    2017-12-15            Star Wars Ep. VIII: The Last Jedi
# 6    2015-12-18         Star Wars Ep. VII: The Force Awakens
# ..          ...                                          ...
# 62   2014-12-31                         Stories of Our Lives
# 72   2015-05-19                             Family Motocross
# 73   2012-01-13                                    Newlyweds
# 78   2018-12-31                                       Red 11
# 81   2015-09-29                         A Plague So Pleasant
#
#     production_budget  domestic_gross  worldwide_gross       US ROI  \
# id
# 2         410600000.0     241063875.0     1.045664e+09 -169536125.0
# 3         350000000.0      42762350.0     1.497624e+08 -307237650.0
# ...

# %%
us_roi = df.sort_values(by=['US ROI'], ascending=False)
global_roi = df.sort_values(by=['Global ROI'], ascending=False)
